# %%
import pandas as pd

# %%
df=pd.read_csv('G:\\wintership\\week 2\\airports.csv')

# %%
df.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
df=pd.read_csv('G:\\wintership\\week 2\\flights.csv',low_memory=False)

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
df=slice(100000)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'slice' object has no attribute 'head'

# %%
df=pd.read_csv('G:\\wintership\\week 2\\flights.csv',low_memory=False)

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
df = df.iloc[:100000]

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7a159a231d1e> in <module>
# ----> 1 info()
#
# NameError: name 'info' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 31 columns):
# YEAR                   100000 non-null int64
# MONTH                  100000 non-null int64
# DAY                    100000 non-null int64
# DAY_OF_WEEK            100000 non-null int64
# AIRLINE                100000 non-null object
# FLIGHT_NUMBER          100000 non-null int64
# TAIL_NUMBER            99833 non-null object
# ORIGIN_AIRPORT         100000 non-null object
# DESTINATION_AIRPORT    100000 non-null object
# SCHEDULED_DEPARTURE    100000 non-null int64
# DEPARTURE_TIME         97702 non-null float64
# DEPARTURE_DELAY        97702 non-null float64
# TAXI_OUT               97629 non-null float64
# WHEELS_OFF             97629 non-null float64
# SCHEDULED_TIME         100000 non-null float64
# ELAPSED_TIME           97387 non-null float64
# AIR_TIME               97387 non-null float64
# DISTANCE               100000 non-null int64
# ...

# %%
df.DIVERTED.value_counts()
# Out:
# 0    99776
# 1      224
# Name: DIVERTED, dtype: int64

# %%
df['result'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'result'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-3234f0743397> in <module>
# ----> 1 df['result'].value_counts()
#       2
# ...

# %%
result = []
sum=0
for i in df['ARRIVAL_DELAY']:
    if i > 15:
        result.append(1)
        sum=sum+1;
    else:
        result.append(0)

# %%
df['result']=result;

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
sum
# Out:
# 33608

# %%
df['result'].value_counts(df.corr(),annot=True,cmap='PuBuGn',fmt='g')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-410bc48c43e7> in <module>
# ----> 1 df['result'].value_counts(df.corr(),annot=True,cmap='PuBuGn',fmt='g')
#
# TypeError: value_counts() got an unexpected keyword argument 'annot'

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot=True,cmap='PuBuGn',fmt='g')

# %%
plt.figsize(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2b5ec2248280> in <module>
# ----> 1 plt.figsize(30)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.figsize(30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-2b5ec2248280> in <module>
# ----> 1 plt.figsize(30)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'figsize'

# %%
plt.figsize(30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-2b5ec2248280> in <module>
# ----> 1 plt.figsize(30)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'figsize'

# %%
plt.figure(figsize=(20,10))

# %%
sns.heatmap(df.corr(),annot=True,cmap='PuBuGn',fmt='g')

# %%
sns.set(rc={'figure.figsize':(35,25)})

# %%
sns.heatmap(df.corr(),annot=True,cmap='PuBuGn',fmt='g')

# %%
del df.'YEAR'
# Out:
#   File "<ipython-input-17-b978ca85351d>", line 1
#     del df.'YEAR'
#                 ^
# SyntaxError: invalid syntax

# %%
del df.YEAR
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-66ae7a5fcc56> in <module>
# ----> 1 del df.YEAR
#
# AttributeError: YEAR

# %%
del df."YEAR"
# Out:
#   File "<ipython-input-19-354dd3ce2a42>", line 1
#     del df."YEAR"
#                 ^
# SyntaxError: invalid syntax

# %%
del df['YEAR']

# %%
df.head()
# Out:
#    MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0      1    1            4      AS             98      N407AS            ANC
# 1      1    1            4      AA           2336      N3KUAA            LAX
# 2      1    1            4      US            840      N171US            SFO
# 3      1    1            4      AA            258      N3HYAA            LAX
# 4      1    1            4      AS            135      N527AS            SEA
#
#   DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  ...  ARRIVAL_TIME  \
# 0                 SEA                    5          2354.0  ...         408.0
# 1                 PBI                   10             2.0  ...         741.0
# 2                 CLT                   20            18.0  ...         811.0
# 3                 MIA                   20            15.0  ...         756.0
# 4                 ANC                   25            24.0  ...         259.0
#
# ...

# %%
del df['FLIGHT_NUMBER','AIRLINE']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('FLIGHT_NUMBER', 'AIRLINE')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-2a23a736c2c0> in <module>
# ...

# %%
del df['FLIGHT_NUMBER']

# %%
del df['AIRLINE']

# %%
del df['DISTANCE']

# %%
del df['TAIL_NUMBER']

# %%
del df['TAXI_OUT']

# %%
del df['SCHDEULED_TIME']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SCHDEULED_TIME'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-407c0913477e> in <module>
# ----> 1 del df['SCHDEULED_TIME']
#
# ...

# %%
del df['SCHEDULED_TIME']

# %%
del df['DEPARTURE_TIME']

# %%
del df['WHEELS_OFF']

# %%
del df['ELAPSED_TIME']

# %%
del df['AIR_TIME']

# %%
del df['WHEELS_ON']

# %%
del df['DAY_OF_WEEK']

# %%
del df['TAXI_IN']

# %%
del df['ARRIVAL_TIME']

# %%
del df['CANCELLATION_REASON']

# %%
df.head()
# Out:
#    MONTH  DAY ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0      1    1            ANC                 SEA                    5
# 1      1    1            LAX                 PBI                   10
# 2      1    1            SFO                 CLT                   20
# 3      1    1            LAX                 MIA                   20
# 4      1    1            SEA                 ANC                   25
#
#    DEPARTURE_DELAY  SCHEDULED_ARRIVAL  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0            -11.0                430          -22.0         0          0
# 1             -8.0                750           -9.0         0          0
# 2             -2.0                806            5.0         0          0
# 3             -5.0                805           -9.0         0          0
# 4             -1.0                320          -21.0         0          0
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# ...

# %%
df.mean()
# Out:
# MONTH                     1.000000
# DAY                       3.733920
# SCHEDULED_DEPARTURE    1306.348280
# DEPARTURE_DELAY          19.937749
# SCHEDULED_ARRIVAL      1481.115620
# ARRIVAL_DELAY            18.342304
# DIVERTED                  0.002240
# CANCELLED                 0.023890
# AIR_SYSTEM_DELAY         14.026801
# SECURITY_DELAY            0.070787
# AIRLINE_DELAY            17.853921
# LATE_AIRCRAFT_DELAY      26.014556
# WEATHER_DELAY             2.751971
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#        MONTH  DAY ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0          1    1            ANC                 SEA                    5
# 1          1    1            LAX                 PBI                   10
# 2          1    1            SFO                 CLT                   20
# 3          1    1            LAX                 MIA                   20
# 4          1    1            SEA                 ANC                   25
# ...      ...  ...            ...                 ...                  ...
# 99995      1    7            ATL                 BQK                 1108
# 99996      1    7            LAS                 PHL                 1108
# 99997      1    7            SFO                 BFL                 1108
# 99998      1    7            ORD                 MCO                 1109
# 99999      1    7            HOU                 DFW                 1109
#
#        DEPARTURE_DELAY  SCHEDULED_ARRIVAL  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# ...

# %%
df.head()
# Out:
#    MONTH  DAY ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0      1    1            ANC                 SEA                    5
# 1      1    1            LAX                 PBI                   10
# 2      1    1            SFO                 CLT                   20
# 3      1    1            LAX                 MIA                   20
# 4      1    1            SEA                 ANC                   25
#
#    DEPARTURE_DELAY  SCHEDULED_ARRIVAL  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0            -11.0                430          -22.0         0          0
# 1             -8.0                750           -9.0         0          0
# 2             -2.0                806            5.0         0          0
# 3             -5.0                805           -9.0         0          0
# 4             -1.0                320          -21.0         0          0
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# ...

# %%
df=df.fillna(df.mean())

# %%
df.head()
# Out:
#    MONTH  DAY ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0      1    1            ANC                 SEA                    5
# 1      1    1            LAX                 PBI                   10
# 2      1    1            SFO                 CLT                   20
# 3      1    1            LAX                 MIA                   20
# 4      1    1            SEA                 ANC                   25
#
#    DEPARTURE_DELAY  SCHEDULED_ARRIVAL  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0            -11.0                430          -22.0         0          0
# 1             -8.0                750           -9.0         0          0
# 2             -2.0                806            5.0         0          0
# 3             -5.0                805           -9.0         0          0
# 4             -1.0                320          -21.0         0          0
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# ...

# %%
df['result']=i
for i in ARRIVAL_DELAY:
    if i > 15:
        result= 1
    else:
        result = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-9f1a49f17daf> in <module>
# ----> 1 df['result']=i
#       2 for i in ARRIVAL_DELAY:
#       3     if i > 15:
#       4         result= 1
#       5     else:
#
# NameError: name 'i' is not defined

# %%
import numpy as np

# %%
df['result'] = np.where(df['ARRIVAL_DELAY'] > 15, True, False)

# %%
df.head()
# Out:
#    MONTH  DAY ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0      1    1            ANC                 SEA                    5
# 1      1    1            LAX                 PBI                   10
# 2      1    1            SFO                 CLT                   20
# 3      1    1            LAX                 MIA                   20
# 4      1    1            SEA                 ANC                   25
#
#    DEPARTURE_DELAY  SCHEDULED_ARRIVAL  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0            -11.0                430          -22.0         0          0
# 1             -8.0                750           -9.0         0          0
# 2             -2.0                806            5.0         0          0
# 3             -5.0                805           -9.0         0          0
# 4             -1.0                320          -21.0         0          0
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# ...

# %%
df['result'] = np.where(df['ARRIVAL_DELAY'] > 15, 1,0)

# %%
df.head()
# Out:
#    MONTH  DAY ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0      1    1            ANC                 SEA                    5
# 1      1    1            LAX                 PBI                   10
# 2      1    1            SFO                 CLT                   20
# 3      1    1            LAX                 MIA                   20
# 4      1    1            SEA                 ANC                   25
#
#    DEPARTURE_DELAY  SCHEDULED_ARRIVAL  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0            -11.0                430          -22.0         0          0
# 1             -8.0                750           -9.0         0          0
# 2             -2.0                806            5.0         0          0
# 3             -5.0                805           -9.0         0          0
# 4             -1.0                320          -21.0         0          0
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# ...

# %%
df['result'].value_counts()
# Out:
# 0    63779
# 1    36221
# Name: result, dtype: int64

# %%
(df['result'].values == '1').sum()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-6e680dabc400> in <module>
# ----> 1 (df['result'].values == '1').sum()
#
# AttributeError: 'bool' object has no attribute 'sum'

# %%
print(df[df.result == '1'].count())
# Out:
# MONTH                  0
# DAY                    0
# ORIGIN_AIRPORT         0
# DESTINATION_AIRPORT    0
# SCHEDULED_DEPARTURE    0
# DEPARTURE_DELAY        0
# SCHEDULED_ARRIVAL      0
# ARRIVAL_DELAY          0
# DIVERTED               0
# CANCELLED              0
# AIR_SYSTEM_DELAY       0
# SECURITY_DELAY         0
# AIRLINE_DELAY          0
# LATE_AIRCRAFT_DELAY    0
# WEATHER_DELAY          0
# result                 0
# dtype: int64

# %%
df.result.value_counts()['1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-03e801c99695> in <module>
# ----> 1 df.result.value_counts()['1']
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
print(len(df[df['result'] == '0']))
# Out:
# 0

# %%
print(len(df[df['result'] == '1']))
# Out:
# 0

# %%
missing2 = df.result.value_counts()['1']
print(missing2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-c272b0b8f4f6> in <module>
# ----> 1 missing2 = df.result.value_counts()['1']
#       2 print(missing2)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
import sklearn as sk
